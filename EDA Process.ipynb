# %% [markdown]
# # Reading the Data Set

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Online Retail.csv")
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# 0       2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1       2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2       2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3       2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4       2010-12-01 08:26:00       3.39       17850  United Kingdom
# ...                     ...        ...         ...             ...
# 541904  2011-12-09 12:50:00       0.85       12680          France
# 541905  2011-12-09 12:50:00       2.10       12680          France
# 541906  2011-12-09 12:50:00       4.15       12680          France
# 541907  2011-12-09 12:50:00       4.15       12680          France
# 541908  2011-12-09 12:50:00       4.95       12680          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# # Knowing the types, count, non-null values of the data set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 534745 entries, 0 to 541908
# Data columns (total 14 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   InvoiceNo             534745 non-null  object
#  1   StockCode             534745 non-null  object
#  2   Description           534745 non-null  object
#  3   Quantity              534745 non-null  int64
#  4   InvoiceDate           534745 non-null  datetime64[ns]
#  5   UnitPrice             534745 non-null  float64
#  6   CustomerID            534745 non-null  int64
#  7   Country               534745 non-null  object
#  8   Month                 534745 non-null  int32
#  9   Month_name_year_wise  534745 non-null  object
#  10  Day                   534745 non-null  int32
#  11  Year                  534745 non-null  int32
#  12  Day_name              534745 non-null  object
#  13  Cost                  534745 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int32(3), int64(2), object(6)
# memory usage: 55.1+ MB

# %% [markdown]
# # Finding the count,mean,max,min of the data set

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  541909.000000
# mean        9.552250       4.611114   15287.518434
# std       218.081158      96.759853    1484.746041
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   14367.000000
# 50%         3.000000       2.080000   15287.000000
# 75%        10.000000       4.130000   16255.000000
# max     80995.000000   38970.000000   18287.000000

# %%
item_type = df.dtypes
item_type
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID       int64
# Country         object
# dtype: object

# %% [markdown]
# # Finding null or na values in the data

# %%
null_values = df.isnull().any()
null_values
# Out:
# InvoiceNo      False
# StockCode      False
# Description     True
# Quantity       False
# InvoiceDate    False
# UnitPrice      False
# CustomerID     False
# Country        False
# dtype: bool

# %% [markdown]
# # Finding how many numbers of null or na values in the individual columns

# %%
null_values_sum = df.isnull().sum()   
null_values_sum
# Out:
# InvoiceNo         0
# StockCode         0
# Description    1454
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# CustomerID        0
# Country           0
# dtype: int64

# %% [markdown]
# # Deleting Null values in Row wise

# %%
df = df.dropna(axis=0)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# 0       2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1       2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2       2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3       2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4       2010-12-01 08:26:00       3.39       17850  United Kingdom
# ...                     ...        ...         ...             ...
# 541904  2011-12-09 12:50:00       0.85       12680          France
# 541905  2011-12-09 12:50:00       2.10       12680          France
# 541906  2011-12-09 12:50:00       4.15       12680          France
# 541907  2011-12-09 12:50:00       4.15       12680          France
# 541908  2011-12-09 12:50:00       4.95       12680          France
#
# [540455 rows x 8 columns]

# %% [markdown]
# # Re-Checking null values

# %%
rechecking_null = df.isnull().sum()
rechecking_null
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# # Counting how many numbers are there and its counts

# %%
quantities = df["Quantity"].value_counts()
quantities
# Out:
# Quantity
#  1      148101
#  2       81763
#  12      61049
#  6       40846
#  4       38461
#          ...
#  212         1
# -179         1
# -428         1
# -224         1
# -149         1
# Name: count, Length: 671, dtype: int64

# %% [markdown]
# # Finding Negative values where exactly in the data set

# %%
negativity_values = df[df["Quantity"] < 0]
negativity_values
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# 141     2010-12-01 09:41:00      27.50       14527  United Kingdom
# 154     2010-12-01 09:49:00       4.65       15311  United Kingdom
# 235     2010-12-01 10:24:00       1.65       17548  United Kingdom
# 236     2010-12-01 10:24:00       0.29       17548  United Kingdom
# 237     2010-12-01 10:24:00       0.29       17548  United Kingdom
# ...                     ...        ...         ...             ...
# 540449  2011-12-09 09:57:00       0.83       14397  United Kingdom
# 541541  2011-12-09 10:28:00     224.69       15498  United Kingdom
# 541715  2011-12-09 11:57:00      10.95       15311  United Kingdom
# 541716  2011-12-09 11:58:00       1.25       17315  United Kingdom
# 541717  2011-12-09 11:58:00       1.25       17315  United Kingdom
#
# [9762 rows x 8 columns]

# %% [markdown]
# # Converting those negative values into positive values

# %%
df["Quantity"] = df["Quantity"].abs()
df
# Out:
# C:\Users\rajro\AppData\Local\Temp\ipykernel_8448\3647483192.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Quantity"] = df["Quantity"].abs()
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# 0       2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1       2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2       2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3       2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4       2010-12-01 08:26:00       3.39       17850  United Kingdom
# ...                     ...        ...         ...             ...
# 541904  2011-12-09 12:50:00       0.85       12680          France
# 541905  2011-12-09 12:50:00       2.10       12680          France
# 541906  2011-12-09 12:50:00       4.15       12680          France
# 541907  2011-12-09 12:50:00       4.15       12680          France
# 541908  2011-12-09 12:50:00       4.95       12680          France
#
# [540455 rows x 8 columns]

# %% [markdown]
# # Finding Negativity values in UnitPrice

# %%
unit_negativity = df[df["UnitPrice"] <0]
unit_negativity
# Out:
#        InvoiceNo StockCode      Description  Quantity          InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1  2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1  2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06       15287  United Kingdom
# 299984  -11062.06       15287  United Kingdom

# %% [markdown]
# # Coverting the negative values of unitprice into positive

# %%
df["UnitPrice"] = df["UnitPrice"].abs()
df
# Out:
# C:\Users\rajro\AppData\Local\Temp\ipykernel_8448\1043795976.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["UnitPrice"] = df["UnitPrice"].abs()
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# 0       2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1       2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2       2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3       2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4       2010-12-01 08:26:00       3.39       17850  United Kingdom
# ...                     ...        ...         ...             ...
# 541904  2011-12-09 12:50:00       0.85       12680          France
# 541905  2011-12-09 12:50:00       2.10       12680          France
# 541906  2011-12-09 12:50:00       4.15       12680          France
# 541907  2011-12-09 12:50:00       4.15       12680          France
# 541908  2011-12-09 12:50:00       4.95       12680          France
#
# [540455 rows x 8 columns]

# %% [markdown]
# # Removing Unspecified country

# %%
df = df[df["Country"] != 'Unspecified']
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# 0       2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1       2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2       2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3       2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4       2010-12-01 08:26:00       3.39       17850  United Kingdom
# ...                     ...        ...         ...             ...
# 541904  2011-12-09 12:50:00       0.85       12680          France
# 541905  2011-12-09 12:50:00       2.10       12680          France
# 541906  2011-12-09 12:50:00       4.15       12680          France
# 541907  2011-12-09 12:50:00       4.15       12680          France
# 541908  2011-12-09 12:50:00       4.95       12680          France
#
# [540009 rows x 8 columns]

# %% [markdown]
# # Rewirting the country name

# %%
df["Country"] = df["Country"].replace("EIRE", "Ireland")
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# 0       2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1       2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2       2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3       2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4       2010-12-01 08:26:00       3.39       17850  United Kingdom
# ...                     ...        ...         ...             ...
# 541904  2011-12-09 12:50:00       0.85       12680          France
# 541905  2011-12-09 12:50:00       2.10       12680          France
# 541906  2011-12-09 12:50:00       4.15       12680          France
# 541907  2011-12-09 12:50:00       4.15       12680          France
# 541908  2011-12-09 12:50:00       4.95       12680          France
#
# [540009 rows x 8 columns]

# %% [markdown]
# # Finding how many number of countries existed and its counts

# %%
country = df["Country"].value_counts() 
country
# Out:
# Country
# United Kingdom          494024
# Germany                   9495
# France                    8557
# Ireland                   8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: count, dtype: int64

# %% [markdown]
# # Removing Duplicates

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# 0       2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1       2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2       2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3       2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4       2010-12-01 08:26:00       3.39       17850  United Kingdom
# ...                     ...        ...         ...             ...
# 541904  2011-12-09 12:50:00       0.85       12680          France
# 541905  2011-12-09 12:50:00       2.10       12680          France
# 541906  2011-12-09 12:50:00       4.15       12680          France
# 541907  2011-12-09 12:50:00       4.15       12680          France
# 541908  2011-12-09 12:50:00       4.95       12680          France
#
# [534745 rows x 8 columns]

# %% [markdown]
# # Finding how many number of description and its counts

# %%
description_count = df["Description"].value_counts()
description_count
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    2357
# REGENCY CAKESTAND 3 TIER              2187
# JUMBO BAG RED RETROSPOT               2156
# PARTY BUNTING                         1720
# LUNCH BAG RED RETROSPOT               1623
#                                       ...
# RUBY GLASS NECKLACE 42"                  1
# sold with wrong barcode                  1
# John Lewis                               1
# SET 10 CARD CHRISTMAS STAMPS 16963       1
# dotcomstock                              1
# Name: count, Length: 4223, dtype: int64

# %% [markdown]
# # Creating Date and Time column

# %%
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])
df["Month"] = df["InvoiceDate"].dt.month
df["Month_name_year_wise"] = df["InvoiceDate"].dt.month_name()
df["Day"] = df["InvoiceDate"].dt.day
df["Year"]  = df["InvoiceDate"].dt.year
df["Day_name"] = df["InvoiceDate"].dt.day_name()
df["Cost"] = df["Quantity"] * df["UnitPrice"]
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Month  \
# 0      2010-12-01 08:26:00       2.55       17850  United Kingdom     12
# 1      2010-12-01 08:26:00       3.39       17850  United Kingdom     12
# 2      2010-12-01 08:26:00       2.75       17850  United Kingdom     12
# 3      2010-12-01 08:26:00       3.39       17850  United Kingdom     12
# 4      2010-12-01 08:26:00       3.39       17850  United Kingdom     12
# ...                    ...        ...         ...             ...    ...
# 541904 2011-12-09 12:50:00       0.85       12680          France     12
# 541905 2011-12-09 12:50:00       2.10       12680          France     12
# 541906 2011-12-09 12:50:00       4.15       12680          France     12
# 541907 2011-12-09 12:50:00       4.15       12680          France     12
# 541908 2011-12-09 12:50:00       4.95       12680          France     12
#
#        Month_name_year_wise  Day  Year   Day_name   Cost
# 0                  December    1  2010  Wednesday  15.30
# 1                  December    1  2010  Wednesday  20.34
# 2                  December    1  2010  Wednesday  22.00
# 3                  December    1  2010  Wednesday  20.34
# 4                  December    1  2010  Wednesday  20.34
# ...                     ...  ...   ...        ...    ...
# 541904             December    9  2011     Friday  10.20
# 541905             December    9  2011     Friday  12.60
# 541906             December    9  2011     Friday  16.60
# 541907             December    9  2011     Friday  16.60
# 541908             December    9  2011     Friday  14.85
#
# [534745 rows x 14 columns]
